# %% [markdown]
# # Olympic Medal Data Analysis

# %%
import pandas as pd

# %%
cd C:\Users\ajinkya.patil\OneDrive - Prime Boiler Services Ltd\Desktop\Python\Ex_Files_Pandas_EssT\Ex_Files_Pandas_EssT\ExerciseFiles\data
# Out:
# C:\Users\ajinkya.patil\OneDrive - Prime Boiler Services Ltd\Desktop\Python\Ex_Files_Pandas_EssT\Ex_Files_Pandas_EssT\ExerciseFiles\data

# %%
pwd
# Out:
# 'C:\\Users\\ajinkya.patil\\OneDrive - Prime Boiler Services Ltd\\Desktop\\Python\\Ex_Files_Pandas_EssT\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data'

# %%
df = pd.read_csv('olympics.csv', skiprows =4 )

# %%
df.head(2)
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming  HERSCHMANN, Otto  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
df.tail(2)
# Out:
#           City  Edition      Sport       Discipline         Athlete  NOC  \
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R   LOPEZ, Mijain  CUB
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS
#
#       Gender       Event Event_gender   Medal
# 29214    Men  96 - 120kg            M    Gold
# 29215    Men  96 - 120kg            M  Silver

# %% [markdown]
# # Q.1 Find type of each column data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # Q.2 Find number of medals won in each year

# %%
df.Edition.value_counts(ascending=True)
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %%
df.sort_values(['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# # Q.3 Find the type of events in which Jesse Owens won medals.

# %%
df[df.Athlete == 'OWENS, Jesse'].Event
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %% [markdown]
# # Q.4 Show the medals won by china in badminton singles sport.

# %%
df[(df.Sport == 'Badminton') & (df.Event == 'singles') & (df.NOC == 'CHN')].sort_values('Athlete')
# Out:
#             City  Edition      Sport Discipline        Athlete  NOC Gender  \
# 27740    Beijing     2008  Badminton  Badminton      CHEN, Jin  CHN    Men
# 21788    Atlanta     1996  Badminton  Badminton    DONG, Jiong  CHN    Men
# 23720     Sydney     2000  Badminton  Badminton  GONG, Zhichao  CHN  Women
# 20047  Barcelona     1992  Badminton  Badminton     HUANG, Hua  CHN  Women
# 23717     Sydney     2000  Badminton  Badminton    JI, Xinpeng  CHN    Men
# 27741    Beijing     2008  Badminton  Badminton       LIN, Dan  CHN    Men
# 20048  Barcelona     1992  Badminton  Badminton  TANG, Jiuhong  CHN  Women
# 23716     Sydney     2000  Badminton  Badminton    XIA, Xuanze  CHN    Men
# 27745    Beijing     2008  Badminton  Badminton  XIE, Xingfang  CHN  Women
# 23719     Sydney     2000  Badminton  Badminton   YE, Zhaoying  CHN  Women
# 25737     Athens     2004  Badminton  Badminton    ZHANG, Ning  CHN  Women
# ...

# %% [markdown]
# # Q.5 Show the number of medals won by each country in olympic games.

# %%
df.NOC.value_counts(ascending = False)
# Out:
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
#        ...
# TGA       1
# DJI       1
# AHO       1
# BDI       1
# AFG       1
# Name: NOC, Length: 138, dtype: int64

# %% [markdown]
# # Q.6 Show the data of women's sprint event.

# %%
df[(df.Gender == 'Women') & (df.Event == ('sprint'))]
# Out:
#             City  Edition    Sport     Discipline                   Athlete  \
# 18656      Seoul     1988  Cycling  Cycling Track  PARASKEVIN-YOUNG, Connie
# 18657      Seoul     1988  Cycling  Cycling Track            SALUMAE, Erika
# 18658      Seoul     1988  Cycling  Cycling Track           LUDING, Christa
# 20345  Barcelona     1992  Cycling  Cycling Track           HARINGA, Ingrid
# 20346  Barcelona     1992  Cycling  Cycling Track            SALUMAE, Erika
# 20347  Barcelona     1992  Cycling  Cycling Track           NEUMANN, Annett
# 22083    Atlanta     1996  Cycling  Cycling Track           HARINGA, Ingrid
# 22084    Atlanta     1996  Cycling  Cycling Track        BALLANGER, Felicia
# 22085    Atlanta     1996  Cycling  Cycling Track          FERRIS, Michelle
# 24046     Sydney     2000  Cycling  Cycling Track           YANOVYCH, Iryna
# 24047     Sydney     2000  Cycling  Cycling Track        BALLANGER, Felicia
# ...

# %% [markdown]
# # Q.7 Find the number of medals won in each event categories throughout history.

# %%
df.Event.value_counts()
# Out:
# football                          1387
# hockey                            1325
# team competition                  1018
# basketball                         940
# eight with coxswain (8+)           918
#                                   ...
# 8m class C                           2
# - 47.63kg (flyweight)                2
# 47.63 - 52.16kg (bantamweight)       2
# 65.77 - 71.67kg (middleweight)       2
# open class A                         1
# Name: Event, Length: 577, dtype: int64

# %% [markdown]
# # Q.8 Plot the number of medals won in each sport categories in year 1896.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df[df.Edition == 1896].Sport.value_counts().plot(kind = 'bar', color = 'Red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q.9 Compare the medals won by chinese men and women in 2008 olympic game.

# %%
import seaborn as sns

# %%
x = df[(df.NOC == 'CHN') & (df.Edition == 2008)].Medal.value_counts()
x.plot(kind = 'bar')
sns.countplot(data= df, x = 'Gender' )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# # Q.10 Plot the number of medals won in each sport categories from the start of Olympic games.

# %%
x = df.value_counts('Sport').plot(kind = 'bar', color = 'Red')
